# %%
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from attention import *
from tensorflow.keras.utils import get_custom_objects
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# %%
def attention_block(g, x):
    """
        g: Output of Parallel Encoder block
        x: Output of Previous Decoder block
    """

    filters = x.shape[-1]

    g_conv = BatchNormalization()(g)
    g_conv = Activation("relu")(g_conv)
    g_conv = Conv2D(filters, (3, 3), padding="same")(g_conv)

    g_pool = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(g_conv)

    x_conv = BatchNormalization()(x)
    x_conv = Activation("relu")(x_conv)
    x_conv = Conv2D(filters, (3, 3), padding="same")(x_conv)

    gc_sum = Add()([g_pool, x_conv])

    gc_conv = BatchNormalization()(gc_sum)
    gc_conv = Activation("relu")(gc_conv)
    gc_conv = Conv2D(filters, (3, 3), padding="same")(gc_conv)

    gc_mul = Multiply()([gc_conv, x])
    return gc_mul

# %%
class GroupedConv2D(object):

# channel haro split mikone be tedade group ha va har group Conv mizane va natije ro baham concat mikone


    def __init__(self, filters, kernel_size, use_keras=True, **kwargs):
        # kernel_size ye liste = [3, 3, 3, 3, ....]
        # self._groups = masalan 3, chon ye adade 
      
        self._groups = len(kernel_size)
        self._channel_axis = -1

        self._convs = []
        splits = self._split_channels(filters, self._groups)
        for i in range(self._groups):
            self._convs.append(self._get_conv2d(splits[i], kernel_size[i], use_keras, **kwargs))

    def _get_conv2d(self, filters, kernel_size, use_keras, **kwargs):
        """A helper function to create Conv2D layer."""
        if use_keras:
            return Conv2D(filters=filters, kernel_size=kernel_size, **kwargs)
        else:
            return Conv2D(filters=filters, kernel_size=kernel_size, **kwargs)

    def _split_channels(self, total_filters, num_groups):
        split = [total_filters // num_groups for _ in range(num_groups)]    
         # masalan:  split = [14, 14, 14, 14] yani tedade channel haro be tedade groups taghsim mikonim
         # tedade channel hayi ke be har group mirese ro moshakhas mikone
        split[0] += total_filters - sum(split)
        return split

    def __call__(self, inputs):
        if len(self._convs) == 1:
            return self._convs[0](inputs)


        filters = inputs.shape[self._channel_axis]
        splits = self._split_channels(filters, len(self._convs))
        x_splits = tf.split(inputs, splits, self._channel_axis)
        # tf.split(tensor, [3, 3, 3, 3, 3], axis=-1)     yani dar rastaye channels feature_map ro tagsim mikone b3 5 ta gesmat ke harkodum 3 ta channel daran
        x_outputs = [c(x) for x, c in zip(x_splits, self._convs)]    # yani be har split Convolution mizanim va natije ro to ye list mizarim
        # [print(xx.shape) for xx in x_outputs]
        x = tf.concat(x_outputs, self._channel_axis)
        # hameye inaro ke natijeye Convolution roye split haye mokhtalef hastan ro baham Concat mikonim
        return x

# %%
# to 2 ta Conv avali tedade filter ha, stem_width ta ast, to Conv sevomi, stem_width*2 ta ast
def make_stem(input_tensor, stem_width=64, active='relu'):      # stem_width: tedade filter hast
    x = input_tensor
    channel_axis = -1
    # inja strides=2 hast va spatial_dimensions nesf mishe
    x = Conv2D(stem_width, kernel_size=3, strides=1, padding="same", kernel_initializer="he_normal",
                use_bias=False, data_format="channels_last")(x)

    x = BatchNormalization(axis=channel_axis, epsilon=1.001e-5)(x)
    x = Activation(active)(x)

    x = Conv2D(stem_width, kernel_size=3, strides=1, padding="same",
                kernel_initializer="he_normal", use_bias=False, data_format="channels_last")(x)

    # Shortcut
    shortcut = Conv2D(stem_width, kernel_size=1, strides=1, padding="same", kernel_initializer="he_normal",
                use_bias=False, data_format="channels_last")(input_tensor)


    # Add
    x = Add()([x, shortcut])

    return x

# %%
def rsoftmax(input_tensor, filters, radix, groups):
# vorodi be _rsoftmax radix-major hast(radix ha bala va groups payin hastan): radix, groups
# shape vorodi va khoroji az r-softmax be in shekle: (batch_size, 1, 1, filters*radix) 
# chon feature-map ke az SeNet migzare varede rsoftmaax mishe

    x = input_tensor
    batch = x.shape[0]

    if radix>1:
        # print('x0', x.shape)
        x = tf.reshape(x, [-1, groups, radix, filters//groups])   # inja group-major mikonim
        # print('x2', x.shape)
        x = tf.transpose(x, [0, 2, 1, 3])              # transpose kardim ta radix-major beshe baraye r-softmax(radix-softmax)
        # yani bad az transpose, shape mishe: (batch_size, radix, groups, filters//groups) yani group_major mishe
        # print('x2', x.shape)
        x = tf.keras.activations.softmax(x, axis=1)   # yani softmax dar rastaye radix ha mizane
        # print('x3', x.shape)
        x = tf.reshape(x, [-1, 1, 1, radix*filters])     # shape in ham mishe (batch_size, 1, 1, radix*filters)
        # print('x4', x.shape)
    else:
        x = Activation('sigmoid')(x)
    return x

# %%
def SplAtConv2d(input_tensor, filters=64, kernel_size=3, dilation=1, groups=2, radix=4, active='relu',  dropout_rate = 0):
    channel_axis = -1
    x = input_tensor
    in_channels = input_tensor.shape[-1]

    x = GroupedConv2D(filters=filters * radix, kernel_size=[kernel_size for i in range(groups * radix)],
                        use_keras=True, padding="same", kernel_initializer="he_normal", use_bias=False,
                        data_format="channels_last", dilation_rate=dilation)(x)
    
    x = BatchNormalization(axis=channel_axis, epsilon=1.001e-5)(x)
    x = Dropout(dropout_rate)(x)
    x = Activation(active)(x)

    batch, rchannel = x.shape[0], x.shape[-1]
    if radix > 1:
        splited = tf.split(x, radix, axis=-1)  # ye list mishe ke len on mishe radix
        gap = sum(splited)
    else:
        gap = x

    # print('sum',gap.shape)
    gap = GlobalAveragePooling2D(data_format="channels_last")(gap)
    gap = tf.reshape(gap, [-1, 1, 1, filters])
    # print('adaptive_avg_pool2d',gap.shape)

    reduction_factor = 4
    inter_channels = max(in_channels * radix // reduction_factor, 32)

    x = Conv2D(inter_channels, kernel_size=1)(gap)   # output_shape: (batch_size, 1, 1, inter_channels)

    x = BatchNormalization(axis=channel_axis, epsilon=1.001e-5)(x)
    x = Dropout(dropout_rate)(x)
    x = Activation(active)(x)
    x = Conv2D(filters * radix, kernel_size=1)(x)
    # output_shape: (batch_size, 1, 1, filters * radix)

    atten = rsoftmax(x, filters, radix, groups)

    if radix > 1:
        logits = tf.split(atten, radix, axis=-1)
        out = sum([a * b for a, b in zip(splited, logits)])
    else:
        out = atten * x
    return out

# %%
def make_block_basic(input_tensor, filters = 64, stride=1, radix= 4, groups= 2, active='relu', dilation=1, bottleneck_width=64, dropout_rate=0.2):
    """Conv2d_BN_Relu->Bn_Relu_Conv2d
    """
        
    x = input_tensor
    channel_axis = -1
    x = BatchNormalization(axis=channel_axis, epsilon=1.001e-5)(x)
    x = Activation(active)(x)

    # Shortcut
    short_cut = x
    inplanes = input_tensor.shape[-1]               # inplanes: num_channels
    short_cut = Conv2D(filters, kernel_size=1, strides=stride, padding="same", kernel_initializer="he_normal",
                        use_bias=False, data_format="channels_last")(short_cut)          # to in spatial_dimensions nesf mishan, tedade filters ham channel darim


    ###
    group_width = filters * groups     # filters * groups : teadade filters dar split_attention

    if radix >= 1:
        x = SplAtConv2d(x, filters=group_width, kernel_size=3, dilation=dilation,
                                groups=groups, radix=radix)
    else:
        x = Conv2D(filters, kernel_size=3, padding="same", kernel_initializer="he_normal",
                    dilation_rate=dilation, use_bias=False, data_format="channels_last")(x)



    x = BatchNormalization(axis=channel_axis, epsilon=1.001e-5)(x)
    x = Dropout(dropout_rate)(x)
    x = Activation(active)(x)
    x = Conv2D(filters, kernel_size=3, strides=stride, padding="same", kernel_initializer="he_normal",
                dilation_rate=dilation, use_bias=False, data_format="channels_last")(x)

    m2 = Add()([x, short_cut])
    # print('x.shape: ', x.shape)
    return m2

# %% [markdown]
# ### Test

# %%
input_tensor = tf.random.uniform(shape=(2, 32, 32, 8))
filters=64
radix = 4
groups=2
kernel_size = 3
dilation = 1
short_cut = input_tensor
inplanes = input_tensor.shape[-1]  
block_expansion=4
avd=True
avd_first=False
avg_down=True
stride=2
cardinality = groups
bottleneck_width=64

# %%
def build_model(input_shape):
    inputs=Input(shape=input_shape)
    c0=inputs
    n_filters=[16,32,64,128,256]
    e1 = make_stem(c0, stem_width=n_filters[0])                         # (256, 256, 16)
    c1 = s_attention(e1)

    ## Encoder
    e2 = make_block_basic(c1, filters = n_filters[1], stride=2, groups=2, radix=4)          # e2, c2 : (batch, 128, 128, 32)
    c2 = s_attention(e2)
    e3 = make_block_basic(c2, filters = n_filters[2], stride=2, groups=2, radix=4)          # e3, c3 : (batch, 64, 64, 64)
    c3 = s_attention(e3) 
    e4 = make_block_basic(c3, filters = n_filters[3], stride=2, groups=2, radix=4)          # (batch, 32, 32, 128)

    ## Bridge
    b1 = dual_attention(e4)        # b1: (batch_size, 32, 32, filters)

    ## Decoder
    d1 = attention_block(c3, b1)      # d1.shape: (batch, 32, 32, 128)
    d1 = UpSampling2D((2, 2))(d1)     # (batch, 64, 64, 128)
    d1 = Concatenate()([d1, e3])      # (batch, 64, 64, 192)
    d1 = make_block_basic(d1, filters = n_filters[3])   # (batch, 64, 64, 128)

    d2 = attention_block(e2, d1)    # (64, 64, 128)
    # print('d2.shape: ', d2.shape)
    d2 = UpSampling2D((2, 2))(d2)   # (batch, 128, 128, 128)
    # print('d2.shape: ', d2.shape)
    d2 = Concatenate()([d2, e2])   # (batch, 128, 128, 160)
    # print('d2.shape: ', d2.shape)        
    d2 = make_block_basic(d2, filters = n_filters[2])   # (batch, 128, 128, 64)
    # print('d2.shape: ', d2.shape)


    d3 = attention_block(e1, d2)   # (batch, 128, 128, 64)
    # print('d3.shape: ', d3.shape)
    d3 = UpSampling2D((2, 2))(d3)  # (batch, 256, 256, 64)
    # print('d3.shape: ', d3.shape)
    d3 = Concatenate()([d3, e1])   # (batch, 256, 256, 80)
    # print('d3.shape: ', d3.shape)
    d3 = make_block_basic(d3, filters = n_filters[1])   # (batch, 256, 256, 32)
    # print('d3.shape: ', d3.shape)

    outputs = s_attention(d3)   # (batch, 256, 256, 32)
    print('outputs.shape: ', outputs.shape)
    outputs = Conv2D(1, (1, 1), padding="same")(outputs)   # (batch, 256, 256, 1)
    outputs = Activation("sigmoid")(outputs)
    print(outputs.shape)

    ## Model
    model = Model(inputs, outputs)
    return model

# %%
if __name__ == "__main__":
    input_shape = (256, 256, 3)
    model = build_model(input_shape)
    model.summary()
# Out:
# outputs.shape:  (None, 256, 256, 32)
# (None, 256, 256, 1)
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_759 (Conv2D)            (None, 256, 256, 16  432         ['input_10[0][0]']
#                                 )
#
#  batch_normalization_309 (Batch  (None, 256, 256, 16  64         ['conv2d_759[0][0]']
#  Normalization)                 )
#
#  activation_317 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_309[0][0]']
#                                 )
#
#  conv2d_760 (Conv2D)            (None, 256, 256, 16  2304        ['activation_317[0][0]']
#                                 )
#
#  conv2d_761 (Conv2D)            (None, 256, 256, 16  48          ['input_10[0][0]']
#                                 )
#
#  add_92 (Add)                   (None, 256, 256, 16  0           ['conv2d_760[0][0]',
#                                 )                                 'conv2d_761[0][0]']
#
#  spatial_attention_35 (spatial_  (None, 256, 256, 16  98         ['add_92[0][0]']
#  attention)                     )
#
#  batch_normalization_310 (Batch  (None, 256, 256, 16  64         ['spatial_attention_35[0][0]']
#  Normalization)                 )
#
#  activation_318 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_310[0][0]']
#                                 )
#
#  tf.split_153 (TFOpLambda)      [(None, 256, 256, 2  0           ['activation_318[0][0]']
#                                 ),
#                                  (None, 256, 256, 2
#                                 ),
#                                  (None, 256, 256, 2
#                                 ),
#                                  (None, 256, 256, 2
#                                 ),
#                                  (None, 256, 256, 2
#                                 ),
#                                  (None, 256, 256, 2
#                                 ),
#                                  (None, 256, 256, 2
#                                 ),
#                                  (None, 256, 256, 2
#                                 )]
#
#  conv2d_763 (Conv2D)            (None, 256, 256, 32  576         ['tf.split_153[0][0]']
#                                 )
#
#  conv2d_764 (Conv2D)            (None, 256, 256, 32  576         ['tf.split_153[0][1]']
#                                 )
#
#  conv2d_765 (Conv2D)            (None, 256, 256, 32  576         ['tf.split_153[0][2]']
#                                 )
#
#  conv2d_766 (Conv2D)            (None, 256, 256, 32  576         ['tf.split_153[0][3]']
#                                 )
#
#  conv2d_767 (Conv2D)            (None, 256, 256, 32  576         ['tf.split_153[0][4]']
#                                 )
#
#  conv2d_768 (Conv2D)            (None, 256, 256, 32  576         ['tf.split_153[0][5]']
#                                 )
#
#  conv2d_769 (Conv2D)            (None, 256, 256, 32  576         ['tf.split_153[0][6]']
#                                 )
#
#  conv2d_770 (Conv2D)            (None, 256, 256, 32  576         ['tf.split_153[0][7]']
#                                 )
#
#  tf.concat_51 (TFOpLambda)      (None, 256, 256, 25  0           ['conv2d_763[0][0]',
#                                 6)                                'conv2d_764[0][0]',
#                                                                   'conv2d_765[0][0]',
#                                                                   'conv2d_766[0][0]',
#                                                                   'conv2d_767[0][0]',
#                                                                   'conv2d_768[0][0]',
#                                                                   'conv2d_769[0][0]',
#                                                                   'conv2d_770[0][0]']
#
#  batch_normalization_311 (Batch  (None, 256, 256, 25  1024       ['tf.concat_51[0][0]']
#  Normalization)                 6)
#
#  dropout_177 (Dropout)          (None, 256, 256, 25  0           ['batch_normalization_311[0][0]']
#                                 6)
#
#  activation_319 (Activation)    (None, 256, 256, 25  0           ['dropout_177[0][0]']
#                                 6)
#
#  tf.split_154 (TFOpLambda)      [(None, 256, 256, 6  0           ['activation_319[0][0]']
#                                 4),
#                                  (None, 256, 256, 6
#                                 4),
#                                  (None, 256, 256, 6
#                                 4),
#                                  (None, 256, 256, 6
#                                 4)]
#
#  tf.__operators__.add_408 (TFOp  (None, 256, 256, 64  0          ['tf.split_154[0][0]']
#  Lambda)                        )
#
#  tf.__operators__.add_409 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_408[0][0]'
#  Lambda)                        )                                , 'tf.split_154[0][1]']
#
#  tf.__operators__.add_410 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_409[0][0]'
#  Lambda)                        )                                , 'tf.split_154[0][2]']
#
#  tf.__operators__.add_411 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_410[0][0]'
#  Lambda)                        )                                , 'tf.split_154[0][3]']
#
#  global_average_pooling2d_51 (G  (None, 64)          0           ['tf.__operators__.add_411[0][0]'
#  lobalAveragePooling2D)                                          ]
#
#  tf.reshape_153 (TFOpLambda)    (None, 1, 1, 64)     0           ['global_average_pooling2d_51[0][
#                                                                  0]']
#
#  conv2d_771 (Conv2D)            (None, 1, 1, 32)     2080        ['tf.reshape_153[0][0]']
#
#  batch_normalization_312 (Batch  (None, 1, 1, 32)    128         ['conv2d_771[0][0]']
#  Normalization)
#
#  dropout_178 (Dropout)          (None, 1, 1, 32)     0           ['batch_normalization_312[0][0]']
#
#  activation_320 (Activation)    (None, 1, 1, 32)     0           ['dropout_178[0][0]']
#
#  conv2d_772 (Conv2D)            (None, 1, 1, 256)    8448        ['activation_320[0][0]']
#
#  tf.reshape_154 (TFOpLambda)    (None, 2, 4, 32)     0           ['conv2d_772[0][0]']
#
#  tf.compat.v1.transpose_51 (TFO  (None, 4, 2, 32)    0           ['tf.reshape_154[0][0]']
#  pLambda)
#
#  tf.nn.softmax_51 (TFOpLambda)  (None, 4, 2, 32)     0           ['tf.compat.v1.transpose_51[0][0]
#                                                                  ']
#
#  tf.reshape_155 (TFOpLambda)    (None, 1, 1, 256)    0           ['tf.nn.softmax_51[0][0]']
#
#  tf.split_155 (TFOpLambda)      [(None, 1, 1, 64),   0           ['tf.reshape_155[0][0]']
#                                  (None, 1, 1, 64),
#                                  (None, 1, 1, 64),
#                                  (None, 1, 1, 64)]
#
#  tf.math.multiply_204 (TFOpLamb  (None, 256, 256, 64  0          ['tf.split_154[0][0]',
#  da)                            )                                 'tf.split_155[0][0]']
#
#  tf.__operators__.add_412 (TFOp  (None, 256, 256, 64  0          ['tf.math.multiply_204[0][0]']
#  Lambda)                        )
#
#  tf.math.multiply_205 (TFOpLamb  (None, 256, 256, 64  0          ['tf.split_154[0][1]',
#  da)                            )                                 'tf.split_155[0][1]']
#
#  tf.__operators__.add_413 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_412[0][0]'
#  Lambda)                        )                                , 'tf.math.multiply_205[0][0]']
#
#  tf.math.multiply_206 (TFOpLamb  (None, 256, 256, 64  0          ['tf.split_154[0][2]',
#  da)                            )                                 'tf.split_155[0][2]']
#
#  tf.__operators__.add_414 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_413[0][0]'
#  Lambda)                        )                                , 'tf.math.multiply_206[0][0]']
#
#  tf.math.multiply_207 (TFOpLamb  (None, 256, 256, 64  0          ['tf.split_154[0][3]',
#  da)                            )                                 'tf.split_155[0][3]']
#
#  tf.__operators__.add_415 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_414[0][0]'
#  Lambda)                        )                                , 'tf.math.multiply_207[0][0]']
#
#  batch_normalization_313 (Batch  (None, 256, 256, 64  256        ['tf.__operators__.add_415[0][0]'
#  Normalization)                 )                                ]
#
#  dropout_179 (Dropout)          (None, 256, 256, 64  0           ['batch_normalization_313[0][0]']
#                                 )
#
#  activation_321 (Activation)    (None, 256, 256, 64  0           ['dropout_179[0][0]']
#                                 )
#
#  conv2d_773 (Conv2D)            (None, 128, 128, 32  18432       ['activation_321[0][0]']
#                                 )
#
#  conv2d_762 (Conv2D)            (None, 128, 128, 32  512         ['activation_318[0][0]']
#                                 )
#
#  add_93 (Add)                   (None, 128, 128, 32  0           ['conv2d_773[0][0]',
#                                 )                                 'conv2d_762[0][0]']
#
#  spatial_attention_36 (spatial_  (None, 128, 128, 32  98         ['add_93[0][0]']
#  attention)                     )
#
#  batch_normalization_314 (Batch  (None, 128, 128, 32  128        ['spatial_attention_36[0][0]']
#  Normalization)                 )
#
#  activation_322 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_314[0][0]']
#                                 )
#
#  tf.split_156 (TFOpLambda)      [(None, 128, 128, 4  0           ['activation_322[0][0]']
#                                 ),
#                                  (None, 128, 128, 4
#                                 ),
#                                  (None, 128, 128, 4
#                                 ),
#                                  (None, 128, 128, 4
#                                 ),
#                                  (None, 128, 128, 4
#                                 ),
#                                  (None, 128, 128, 4
#                                 ),
#                                  (None, 128, 128, 4
#                                 ),
#                                  (None, 128, 128, 4
#                                 )]
#
#  conv2d_775 (Conv2D)            (None, 128, 128, 64  2304        ['tf.split_156[0][0]']
#                                 )
#
#  conv2d_776 (Conv2D)            (None, 128, 128, 64  2304        ['tf.split_156[0][1]']
#                                 )
#
#  conv2d_777 (Conv2D)            (None, 128, 128, 64  2304        ['tf.split_156[0][2]']
#                                 )
#
#  conv2d_778 (Conv2D)            (None, 128, 128, 64  2304        ['tf.split_156[0][3]']
#                                 )
#
#  conv2d_779 (Conv2D)            (None, 128, 128, 64  2304        ['tf.split_156[0][4]']
#                                 )
#
#  conv2d_780 (Conv2D)            (None, 128, 128, 64  2304        ['tf.split_156[0][5]']
#                                 )
#
#  conv2d_781 (Conv2D)            (None, 128, 128, 64  2304        ['tf.split_156[0][6]']
#                                 )
#
#  conv2d_782 (Conv2D)            (None, 128, 128, 64  2304        ['tf.split_156[0][7]']
#                                 )
#
#  tf.concat_52 (TFOpLambda)      (None, 128, 128, 51  0           ['conv2d_775[0][0]',
#                                 2)                                'conv2d_776[0][0]',
#                                                                   'conv2d_777[0][0]',
#                                                                   'conv2d_778[0][0]',
#                                                                   'conv2d_779[0][0]',
#                                                                   'conv2d_780[0][0]',
#                                                                   'conv2d_781[0][0]',
#                                                                   'conv2d_782[0][0]']
#
#  batch_normalization_315 (Batch  (None, 128, 128, 51  2048       ['tf.concat_52[0][0]']
#  Normalization)                 2)
#
#  dropout_180 (Dropout)          (None, 128, 128, 51  0           ['batch_normalization_315[0][0]']
#                                 2)
#
#  activation_323 (Activation)    (None, 128, 128, 51  0           ['dropout_180[0][0]']
#                                 2)
#
#  tf.split_157 (TFOpLambda)      [(None, 128, 128, 1  0           ['activation_323[0][0]']
#                                 28),
#                                  (None, 128, 128, 1
#                                 28),
#                                  (None, 128, 128, 1
#                                 28),
#                                  (None, 128, 128, 1
#                                 28)]
#
#  tf.__operators__.add_416 (TFOp  (None, 128, 128, 12  0          ['tf.split_157[0][0]']
#  Lambda)                        8)
#
#  tf.__operators__.add_417 (TFOp  (None, 128, 128, 12  0          ['tf.__operators__.add_416[0][0]'
#  Lambda)                        8)                               , 'tf.split_157[0][1]']
#
#  tf.__operators__.add_418 (TFOp  (None, 128, 128, 12  0          ['tf.__operators__.add_417[0][0]'
#  Lambda)                        8)                               , 'tf.split_157[0][2]']
#
#  tf.__operators__.add_419 (TFOp  (None, 128, 128, 12  0          ['tf.__operators__.add_418[0][0]'
#  Lambda)                        8)                               , 'tf.split_157[0][3]']
#
#  global_average_pooling2d_52 (G  (None, 128)         0           ['tf.__operators__.add_419[0][0]'
#  lobalAveragePooling2D)                                          ]
#
#  tf.reshape_156 (TFOpLambda)    (None, 1, 1, 128)    0           ['global_average_pooling2d_52[0][
#                                                                  0]']
#
#  conv2d_783 (Conv2D)            (None, 1, 1, 32)     4128        ['tf.reshape_156[0][0]']
#
#  batch_normalization_316 (Batch  (None, 1, 1, 32)    128         ['conv2d_783[0][0]']
#  Normalization)
#
#  dropout_181 (Dropout)          (None, 1, 1, 32)     0           ['batch_normalization_316[0][0]']
#
#  activation_324 (Activation)    (None, 1, 1, 32)     0           ['dropout_181[0][0]']
#
#  conv2d_784 (Conv2D)            (None, 1, 1, 512)    16896       ['activation_324[0][0]']
#
#  tf.reshape_157 (TFOpLambda)    (None, 2, 4, 64)     0           ['conv2d_784[0][0]']
#
#  tf.compat.v1.transpose_52 (TFO  (None, 4, 2, 64)    0           ['tf.reshape_157[0][0]']
#  pLambda)
#
#  tf.nn.softmax_52 (TFOpLambda)  (None, 4, 2, 64)     0           ['tf.compat.v1.transpose_52[0][0]
#                                                                  ']
#
#  tf.reshape_158 (TFOpLambda)    (None, 1, 1, 512)    0           ['tf.nn.softmax_52[0][0]']
#
#  tf.split_158 (TFOpLambda)      [(None, 1, 1, 128),  0           ['tf.reshape_158[0][0]']
#                                  (None, 1, 1, 128),
#                                  (None, 1, 1, 128),
#                                  (None, 1, 1, 128)]
#
#  tf.math.multiply_208 (TFOpLamb  (None, 128, 128, 12  0          ['tf.split_157[0][0]',
#  da)                            8)                                'tf.split_158[0][0]']
#
#  tf.__operators__.add_420 (TFOp  (None, 128, 128, 12  0          ['tf.math.multiply_208[0][0]']
#  Lambda)                        8)
#
#  tf.math.multiply_209 (TFOpLamb  (None, 128, 128, 12  0          ['tf.split_157[0][1]',
#  da)                            8)                                'tf.split_158[0][1]']
#
#  tf.__operators__.add_421 (TFOp  (None, 128, 128, 12  0          ['tf.__operators__.add_420[0][0]'
#  Lambda)                        8)                               , 'tf.math.multiply_209[0][0]']
#
#  tf.math.multiply_210 (TFOpLamb  (None, 128, 128, 12  0          ['tf.split_157[0][2]',
#  da)                            8)                                'tf.split_158[0][2]']
#
#  tf.__operators__.add_422 (TFOp  (None, 128, 128, 12  0          ['tf.__operators__.add_421[0][0]'
#  Lambda)                        8)                               , 'tf.math.multiply_210[0][0]']
#
#  tf.math.multiply_211 (TFOpLamb  (None, 128, 128, 12  0          ['tf.split_157[0][3]',
#  da)                            8)                                'tf.split_158[0][3]']
#
#  tf.__operators__.add_423 (TFOp  (None, 128, 128, 12  0          ['tf.__operators__.add_422[0][0]'
#  Lambda)                        8)                               , 'tf.math.multiply_211[0][0]']
#
#  batch_normalization_317 (Batch  (None, 128, 128, 12  512        ['tf.__operators__.add_423[0][0]'
#  Normalization)                 8)                               ]
#
#  dropout_182 (Dropout)          (None, 128, 128, 12  0           ['batch_normalization_317[0][0]']
#                                 8)
#
#  activation_325 (Activation)    (None, 128, 128, 12  0           ['dropout_182[0][0]']
#                                 8)
#
#  conv2d_785 (Conv2D)            (None, 64, 64, 64)   73728       ['activation_325[0][0]']
#
#  conv2d_774 (Conv2D)            (None, 64, 64, 64)   2048        ['activation_322[0][0]']
#
#  add_94 (Add)                   (None, 64, 64, 64)   0           ['conv2d_785[0][0]',
#                                                                   'conv2d_774[0][0]']
#
#  spatial_attention_37 (spatial_  (None, 64, 64, 64)  98          ['add_94[0][0]']
#  attention)
#
#  batch_normalization_318 (Batch  (None, 64, 64, 64)  256         ['spatial_attention_37[0][0]']
#  Normalization)
#
#  activation_326 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_318[0][0]']
#
#  tf.split_159 (TFOpLambda)      [(None, 64, 64, 8),  0           ['activation_326[0][0]']
#                                  (None, 64, 64, 8),
#                                  (None, 64, 64, 8),
#                                  (None, 64, 64, 8),
#                                  (None, 64, 64, 8),
#                                  (None, 64, 64, 8),
#                                  (None, 64, 64, 8),
#                                  (None, 64, 64, 8)]
#
#  conv2d_787 (Conv2D)            (None, 64, 64, 128)  9216        ['tf.split_159[0][0]']
#
#  conv2d_788 (Conv2D)            (None, 64, 64, 128)  9216        ['tf.split_159[0][1]']
#
#  conv2d_789 (Conv2D)            (None, 64, 64, 128)  9216        ['tf.split_159[0][2]']
#
#  conv2d_790 (Conv2D)            (None, 64, 64, 128)  9216        ['tf.split_159[0][3]']
#
#  conv2d_791 (Conv2D)            (None, 64, 64, 128)  9216        ['tf.split_159[0][4]']
#
#  conv2d_792 (Conv2D)            (None, 64, 64, 128)  9216        ['tf.split_159[0][5]']
#
#  conv2d_793 (Conv2D)            (None, 64, 64, 128)  9216        ['tf.split_159[0][6]']
#
#  conv2d_794 (Conv2D)            (None, 64, 64, 128)  9216        ['tf.split_159[0][7]']
#
#  tf.concat_53 (TFOpLambda)      (None, 64, 64, 1024  0           ['conv2d_787[0][0]',
#                                 )                                 'conv2d_788[0][0]',
#                                                                   'conv2d_789[0][0]',
#                                                                   'conv2d_790[0][0]',
#                                                                   'conv2d_791[0][0]',
#                                                                   'conv2d_792[0][0]',
#                                                                   'conv2d_793[0][0]',
#                                                                   'conv2d_794[0][0]']
#
#  batch_normalization_319 (Batch  (None, 64, 64, 1024  4096       ['tf.concat_53[0][0]']
#  Normalization)                 )
#
#  dropout_183 (Dropout)          (None, 64, 64, 1024  0           ['batch_normalization_319[0][0]']
#                                 )
#
#  activation_327 (Activation)    (None, 64, 64, 1024  0           ['dropout_183[0][0]']
#                                 )
#
#  tf.split_160 (TFOpLambda)      [(None, 64, 64, 256  0           ['activation_327[0][0]']
#                                 ),
#                                  (None, 64, 64, 256
#                                 ),
#                                  (None, 64, 64, 256
#                                 ),
#                                  (None, 64, 64, 256
#                                 )]
#
#  tf.__operators__.add_424 (TFOp  (None, 64, 64, 256)  0          ['tf.split_160[0][0]']
#  Lambda)
#
#  tf.__operators__.add_425 (TFOp  (None, 64, 64, 256)  0          ['tf.__operators__.add_424[0][0]'
#  Lambda)                                                         , 'tf.split_160[0][1]']
#
#  tf.__operators__.add_426 (TFOp  (None, 64, 64, 256)  0          ['tf.__operators__.add_425[0][0]'
#  Lambda)                                                         , 'tf.split_160[0][2]']
#
#  tf.__operators__.add_427 (TFOp  (None, 64, 64, 256)  0          ['tf.__operators__.add_426[0][0]'
#  Lambda)                                                         , 'tf.split_160[0][3]']
#
#  global_average_pooling2d_53 (G  (None, 256)         0           ['tf.__operators__.add_427[0][0]'
#  lobalAveragePooling2D)                                          ]
#
#  tf.reshape_159 (TFOpLambda)    (None, 1, 1, 256)    0           ['global_average_pooling2d_53[0][
#                                                                  0]']
#
#  conv2d_795 (Conv2D)            (None, 1, 1, 64)     16448       ['tf.reshape_159[0][0]']
#
#  batch_normalization_320 (Batch  (None, 1, 1, 64)    256         ['conv2d_795[0][0]']
#  Normalization)
#
#  dropout_184 (Dropout)          (None, 1, 1, 64)     0           ['batch_normalization_320[0][0]']
#
#  activation_328 (Activation)    (None, 1, 1, 64)     0           ['dropout_184[0][0]']
#
#  conv2d_796 (Conv2D)            (None, 1, 1, 1024)   66560       ['activation_328[0][0]']
#
#  tf.reshape_160 (TFOpLambda)    (None, 2, 4, 128)    0           ['conv2d_796[0][0]']
#
#  tf.compat.v1.transpose_53 (TFO  (None, 4, 2, 128)   0           ['tf.reshape_160[0][0]']
#  pLambda)
#
#  tf.nn.softmax_53 (TFOpLambda)  (None, 4, 2, 128)    0           ['tf.compat.v1.transpose_53[0][0]
#                                                                  ']
#
#  tf.reshape_161 (TFOpLambda)    (None, 1, 1, 1024)   0           ['tf.nn.softmax_53[0][0]']
#
#  tf.split_161 (TFOpLambda)      [(None, 1, 1, 256),  0           ['tf.reshape_161[0][0]']
#                                  (None, 1, 1, 256),
#                                  (None, 1, 1, 256),
#                                  (None, 1, 1, 256)]
#
#  tf.math.multiply_212 (TFOpLamb  (None, 64, 64, 256)  0          ['tf.split_160[0][0]',
#  da)                                                              'tf.split_161[0][0]']
#
#  tf.__operators__.add_428 (TFOp  (None, 64, 64, 256)  0          ['tf.math.multiply_212[0][0]']
#  Lambda)
#
#  tf.math.multiply_213 (TFOpLamb  (None, 64, 64, 256)  0          ['tf.split_160[0][1]',
#  da)                                                              'tf.split_161[0][1]']
#
#  tf.__operators__.add_429 (TFOp  (None, 64, 64, 256)  0          ['tf.__operators__.add_428[0][0]'
#  Lambda)                                                         , 'tf.math.multiply_213[0][0]']
#
#  tf.math.multiply_214 (TFOpLamb  (None, 64, 64, 256)  0          ['tf.split_160[0][2]',
#  da)                                                              'tf.split_161[0][2]']
#
#  tf.__operators__.add_430 (TFOp  (None, 64, 64, 256)  0          ['tf.__operators__.add_429[0][0]'
#  Lambda)                                                         , 'tf.math.multiply_214[0][0]']
#
#  tf.math.multiply_215 (TFOpLamb  (None, 64, 64, 256)  0          ['tf.split_160[0][3]',
#  da)                                                              'tf.split_161[0][3]']
#
#  tf.__operators__.add_431 (TFOp  (None, 64, 64, 256)  0          ['tf.__operators__.add_430[0][0]'
#  Lambda)                                                         , 'tf.math.multiply_215[0][0]']
#
#  batch_normalization_321 (Batch  (None, 64, 64, 256)  1024       ['tf.__operators__.add_431[0][0]'
#  Normalization)                                                  ]
#
#  dropout_185 (Dropout)          (None, 64, 64, 256)  0           ['batch_normalization_321[0][0]']
#
#  activation_329 (Activation)    (None, 64, 64, 256)  0           ['dropout_185[0][0]']
#
#  conv2d_797 (Conv2D)            (None, 32, 32, 128)  294912      ['activation_329[0][0]']
# ...
#                                 0),
#                                  (None, 256, 256, 1
#                                 0),
#                                  (None, 256, 256, 1
#                                 0),
#                                  (None, 256, 256, 1
#                                 0),
#                                  (None, 256, 256, 1
#                                 0),
#                                  (None, 256, 256, 1
#                                 0),
#                                  (None, 256, 256, 1
#                                 0)]
#
#  conv2d_837 (Conv2D)            (None, 256, 256, 32  2880        ['tf.split_168[0][0]']
#                                 )
#
#  conv2d_838 (Conv2D)            (None, 256, 256, 32  2880        ['tf.split_168[0][1]']
#                                 )
#
#  conv2d_839 (Conv2D)            (None, 256, 256, 32  2880        ['tf.split_168[0][2]']
#                                 )
#
#  conv2d_840 (Conv2D)            (None, 256, 256, 32  2880        ['tf.split_168[0][3]']
#                                 )
#
#  conv2d_841 (Conv2D)            (None, 256, 256, 32  2880        ['tf.split_168[0][4]']
#                                 )
#
#  conv2d_842 (Conv2D)            (None, 256, 256, 32  2880        ['tf.split_168[0][5]']
#                                 )
#
#  conv2d_843 (Conv2D)            (None, 256, 256, 32  2880        ['tf.split_168[0][6]']
#                                 )
#
#  conv2d_844 (Conv2D)            (None, 256, 256, 32  2880        ['tf.split_168[0][7]']
#                                 )
#
#  tf.concat_56 (TFOpLambda)      (None, 256, 256, 25  0           ['conv2d_837[0][0]',
#                                 6)                                'conv2d_838[0][0]',
#                                                                   'conv2d_839[0][0]',
#                                                                   'conv2d_840[0][0]',
#                                                                   'conv2d_841[0][0]',
#                                                                   'conv2d_842[0][0]',
#                                                                   'conv2d_843[0][0]',
#                                                                   'conv2d_844[0][0]']
#
#  batch_normalization_343 (Batch  (None, 256, 256, 25  1024       ['tf.concat_56[0][0]']
#  Normalization)                 6)
#
#  dropout_195 (Dropout)          (None, 256, 256, 25  0           ['batch_normalization_343[0][0]']
#                                 6)
#
#  activation_351 (Activation)    (None, 256, 256, 25  0           ['dropout_195[0][0]']
#                                 6)
#
#  tf.split_169 (TFOpLambda)      [(None, 256, 256, 6  0           ['activation_351[0][0]']
#                                 4),
#                                  (None, 256, 256, 6
#                                 4),
#                                  (None, 256, 256, 6
#                                 4),
#                                  (None, 256, 256, 6
#                                 4)]
#
#  tf.__operators__.add_448 (TFOp  (None, 256, 256, 64  0          ['tf.split_169[0][0]']
#  Lambda)                        )
#
#  tf.__operators__.add_449 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_448[0][0]'
#  Lambda)                        )                                , 'tf.split_169[0][1]']
#
#  tf.__operators__.add_450 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_449[0][0]'
#  Lambda)                        )                                , 'tf.split_169[0][2]']
#
#  tf.__operators__.add_451 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_450[0][0]'
#  Lambda)                        )                                , 'tf.split_169[0][3]']
#
#  global_average_pooling2d_56 (G  (None, 64)          0           ['tf.__operators__.add_451[0][0]'
#  lobalAveragePooling2D)                                          ]
#
#  tf.reshape_168 (TFOpLambda)    (None, 1, 1, 64)     0           ['global_average_pooling2d_56[0][
#                                                                  0]']
#
#  conv2d_845 (Conv2D)            (None, 1, 1, 80)     5200        ['tf.reshape_168[0][0]']
#
#  batch_normalization_344 (Batch  (None, 1, 1, 80)    320         ['conv2d_845[0][0]']
#  Normalization)
#
#  dropout_196 (Dropout)          (None, 1, 1, 80)     0           ['batch_normalization_344[0][0]']
#
#  activation_352 (Activation)    (None, 1, 1, 80)     0           ['dropout_196[0][0]']
#
#  conv2d_846 (Conv2D)            (None, 1, 1, 256)    20736       ['activation_352[0][0]']
#
#  tf.reshape_169 (TFOpLambda)    (None, 2, 4, 32)     0           ['conv2d_846[0][0]']
#
#  tf.compat.v1.transpose_56 (TFO  (None, 4, 2, 32)    0           ['tf.reshape_169[0][0]']
#  pLambda)
#
#  tf.nn.softmax_56 (TFOpLambda)  (None, 4, 2, 32)     0           ['tf.compat.v1.transpose_56[0][0]
#                                                                  ']
#
#  tf.reshape_170 (TFOpLambda)    (None, 1, 1, 256)    0           ['tf.nn.softmax_56[0][0]']
#
#  tf.split_170 (TFOpLambda)      [(None, 1, 1, 64),   0           ['tf.reshape_170[0][0]']
#                                  (None, 1, 1, 64),
#                                  (None, 1, 1, 64),
#                                  (None, 1, 1, 64)]
#
#  tf.math.multiply_224 (TFOpLamb  (None, 256, 256, 64  0          ['tf.split_169[0][0]',
#  da)                            )                                 'tf.split_170[0][0]']
#
#  tf.__operators__.add_452 (TFOp  (None, 256, 256, 64  0          ['tf.math.multiply_224[0][0]']
#  Lambda)                        )
#
#  tf.math.multiply_225 (TFOpLamb  (None, 256, 256, 64  0          ['tf.split_169[0][1]',
#  da)                            )                                 'tf.split_170[0][1]']
#
#  tf.__operators__.add_453 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_452[0][0]'
#  Lambda)                        )                                , 'tf.math.multiply_225[0][0]']
#
#  tf.math.multiply_226 (TFOpLamb  (None, 256, 256, 64  0          ['tf.split_169[0][2]',
#  da)                            )                                 'tf.split_170[0][2]']
#
#  tf.__operators__.add_454 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_453[0][0]'
#  Lambda)                        )                                , 'tf.math.multiply_226[0][0]']
#
#  tf.math.multiply_227 (TFOpLamb  (None, 256, 256, 64  0          ['tf.split_169[0][3]',
#  da)                            )                                 'tf.split_170[0][3]']
#
#  tf.__operators__.add_455 (TFOp  (None, 256, 256, 64  0          ['tf.__operators__.add_454[0][0]'
#  Lambda)                        )                                , 'tf.math.multiply_227[0][0]']
#
#  batch_normalization_345 (Batch  (None, 256, 256, 64  256        ['tf.__operators__.add_455[0][0]'
#  Normalization)                 )                                ]
#
#  dropout_197 (Dropout)          (None, 256, 256, 64  0           ['batch_normalization_345[0][0]']
#                                 )
#
#  activation_353 (Activation)    (None, 256, 256, 64  0           ['dropout_197[0][0]']
#                                 )
#
#  conv2d_847 (Conv2D)            (None, 256, 256, 32  18432       ['activation_353[0][0]']
#                                 )
#
#  conv2d_836 (Conv2D)            (None, 256, 256, 32  2560        ['activation_350[0][0]']
#                                 )
#
#  add_102 (Add)                  (None, 256, 256, 32  0           ['conv2d_847[0][0]',
#                                 )                                 'conv2d_836[0][0]']
#
#  spatial_attention_38 (spatial_  (None, 256, 256, 32  98         ['add_102[0][0]']
#  attention)                     )
#
#  conv2d_848 (Conv2D)            (None, 256, 256, 1)  33          ['spatial_attention_38[0][0]']
#
#  activation_354 (Activation)    (None, 256, 256, 1)  0           ['conv2d_848[0][0]']
#
# ==================================================================================================
# Total params: 2,575,929
# Trainable params: 2,562,969
# Non-trainable params: 12,960
# __________________________________________________________________________________________________
