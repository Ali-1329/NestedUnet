# %%
"""
ResUNet++ architecture in Keras TensorFlow
"""
import os
import numpy as np
import cv2

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

# %%
def squeeze_excite_block(inputs, ratio=8):
    init = inputs
    channel_axis = -1
    filters = init.shape[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)

    x = Multiply()([init, se])
    return x


def stem_block(x, n_filter, strides):
    x_init = x

    ## Conv 1
    x = Conv2D(n_filter, (3, 3), padding="same", strides=strides)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(n_filter, (3, 3), padding="same")(x)

    ## Shortcut
    s  = Conv2D(n_filter, (1, 1), padding="same", strides=strides)(x_init)
    s = BatchNormalization()(s)

    ## Add
    x = Add()([x, s])
    x = squeeze_excite_block(x)
    return x


def resnet_block(x, n_filter, strides=1):
    x_init = x

    ## Conv 1
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(n_filter, (3, 3), padding="same", strides=strides)(x)
    ## Conv 2
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(n_filter, (3, 3), padding="same", strides=1)(x)

    ## Shortcut
    s  = Conv2D(n_filter, (1, 1), padding="same", strides=strides)(x_init)
    s = BatchNormalization()(s)

    ## Add
    x = Add()([x, s])
    x = squeeze_excite_block(x)
    return x


def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y


def attetion_block(g, x):
    """
        g: Output of Parallel Encoder block
        x: Output of Previous Decoder block
    """

    filters = x.shape[-1]

    g_conv = BatchNormalization()(g)
    g_conv = Activation("relu")(g_conv)
    g_conv = Conv2D(filters, (3, 3), padding="same")(g_conv)

    g_pool = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(g_conv)

    x_conv = BatchNormalization()(x)
    x_conv = Activation("relu")(x_conv)
    x_conv = Conv2D(filters, (3, 3), padding="same")(x_conv)

    gc_sum = Add()([g_pool, x_conv])

    gc_conv = BatchNormalization()(gc_sum)
    gc_conv = Activation("relu")(gc_conv)
    gc_conv = Conv2D(filters, (3, 3), padding="same")(gc_conv)

    gc_mul = Multiply()([gc_conv, x])
    return gc_mul

# %%
def build_model(input_shape):
    inputs=Input(shape=input_shape)
    c0=inputs
    n_filters=[16,32,64,128,256]
    c1 = stem_block(c0, n_filters[0], strides=1)

        ## Encoder
    c2 = resnet_block(c1, n_filters[1], strides=2)
    c3 = resnet_block(c2, n_filters[2], strides=2)
    c4 = resnet_block(c3, n_filters[3], strides=2)

    ## Bridge
    b1 = aspp_block(c4, n_filters[4])   # (batch, 32, 32, 256)
    print('b1.shape: ', b1.shape)  

    # Decoder
    d1 = attetion_block(c3, b1)   # (batch, 32, 32, 256)
    # print('d1.shape: ', d1.shape)
    d1 = UpSampling2D((2, 2))(d1)   # (64, 64, 256)
    # print('d1.shape: ', d1.shape)
    d1 = Concatenate()([d1, c3])   # (batch, 64, 64, 320)
    # print('d1.shape: ', d1.shape)
    d1 = resnet_block(d1, n_filters[3])   # (batch, 64, 64, 128)
    # print('d1.shape: ', d1.shape)

    d2 = attetion_block(c2, d1)
    print('d2.shape: ', d2.shape)
    d2 = UpSampling2D((2, 2))(d2)
    print('d2.shape: ', d2.shape)
    d2 = Concatenate()([d2, c2])
    print('d2.shape: ', d2.shape)
    d2 = resnet_block(d2, n_filters[2])
    print('d2.shape: ', d2.shape)

    d3 = attetion_block(c1, d2)
    d3 = UpSampling2D((2, 2))(d3)
    d3 = Concatenate()([d3, c1])
    d3 = resnet_block(d3, n_filters[1])

    ## output
    outputs = aspp_block(d3, n_filters[0])
    outputs = Conv2D(1, (1, 1), padding="same")(outputs)
    outputs = Activation("sigmoid")(outputs)

    ## Model
    model = Model(inputs, outputs)
    return model   


if __name__ == "__main__":
    input_shape = (256, 256, 3)
    model = build_model(input_shape)
    model.summary()
# Out:
# b1.shape:  (None, 32, 32, 256)
# d2.shape:  (None, 64, 64, 128)
# d2.shape:  (None, 128, 128, 128)
# d2.shape:  (None, 128, 128, 160)
# d2.shape:  (None, 128, 128, 64)
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_205 (Conv2D)            (None, 256, 256, 16  448         ['input_6[0][0]']
#                                 )
#
#  batch_normalization_185 (Batch  (None, 256, 256, 16  64         ['conv2d_205[0][0]']
#  Normalization)                 )
#
#  activation_115 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_185[0][0]']
#                                 )
#
#  conv2d_207 (Conv2D)            (None, 256, 256, 16  64          ['input_6[0][0]']
#                                 )
#
#  conv2d_206 (Conv2D)            (None, 256, 256, 16  2320        ['activation_115[0][0]']
#                                 )
#
#  batch_normalization_186 (Batch  (None, 256, 256, 16  64         ['conv2d_207[0][0]']
#  Normalization)                 )
#
#  add_60 (Add)                   (None, 256, 256, 16  0           ['conv2d_206[0][0]',
#                                 )                                 'batch_normalization_186[0][0]']
#
#  global_average_pooling2d_35 (G  (None, 16)          0           ['add_60[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_35 (Reshape)           (None, 1, 1, 16)     0           ['global_average_pooling2d_35[0][
#                                                                  0]']
#
#  dense_70 (Dense)               (None, 1, 1, 2)      32          ['reshape_35[0][0]']
#
#  dense_71 (Dense)               (None, 1, 1, 16)     32          ['dense_70[0][0]']
#
#  multiply_50 (Multiply)         (None, 256, 256, 16  0           ['add_60[0][0]',
#                                 )                                 'dense_71[0][0]']
#
#  batch_normalization_187 (Batch  (None, 256, 256, 16  64         ['multiply_50[0][0]']
#  Normalization)                 )
#
#  activation_116 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_187[0][0]']
#                                 )
#
#  conv2d_208 (Conv2D)            (None, 128, 128, 32  4640        ['activation_116[0][0]']
#                                 )
#
#  batch_normalization_188 (Batch  (None, 128, 128, 32  128        ['conv2d_208[0][0]']
#  Normalization)                 )
#
#  activation_117 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_188[0][0]']
#                                 )
#
#  conv2d_210 (Conv2D)            (None, 128, 128, 32  544         ['multiply_50[0][0]']
#                                 )
#
#  conv2d_209 (Conv2D)            (None, 128, 128, 32  9248        ['activation_117[0][0]']
#                                 )
#
#  batch_normalization_189 (Batch  (None, 128, 128, 32  128        ['conv2d_210[0][0]']
#  Normalization)                 )
#
#  add_61 (Add)                   (None, 128, 128, 32  0           ['conv2d_209[0][0]',
#                                 )                                 'batch_normalization_189[0][0]']
#
#  global_average_pooling2d_36 (G  (None, 32)          0           ['add_61[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_36 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_36[0][
#                                                                  0]']
#
#  dense_72 (Dense)               (None, 1, 1, 4)      128         ['reshape_36[0][0]']
#
#  dense_73 (Dense)               (None, 1, 1, 32)     128         ['dense_72[0][0]']
#
#  multiply_51 (Multiply)         (None, 128, 128, 32  0           ['add_61[0][0]',
#                                 )                                 'dense_73[0][0]']
#
#  batch_normalization_190 (Batch  (None, 128, 128, 32  128        ['multiply_51[0][0]']
#  Normalization)                 )
#
#  activation_118 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_190[0][0]']
#                                 )
#
#  conv2d_211 (Conv2D)            (None, 64, 64, 64)   18496       ['activation_118[0][0]']
#
#  batch_normalization_191 (Batch  (None, 64, 64, 64)  256         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_191[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 64, 64, 64)   2112        ['multiply_51[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 64, 64, 64)   36928       ['activation_119[0][0]']
#
#  batch_normalization_192 (Batch  (None, 64, 64, 64)  256         ['conv2d_213[0][0]']
#  Normalization)
#
#  add_62 (Add)                   (None, 64, 64, 64)   0           ['conv2d_212[0][0]',
#                                                                   'batch_normalization_192[0][0]']
#
#  global_average_pooling2d_37 (G  (None, 64)          0           ['add_62[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_37 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_37[0][
#                                                                  0]']
#
#  dense_74 (Dense)               (None, 1, 1, 8)      512         ['reshape_37[0][0]']
#
#  dense_75 (Dense)               (None, 1, 1, 64)     512         ['dense_74[0][0]']
#
#  multiply_52 (Multiply)         (None, 64, 64, 64)   0           ['add_62[0][0]',
#                                                                   'dense_75[0][0]']
#
#  batch_normalization_193 (Batch  (None, 64, 64, 64)  256         ['multiply_52[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_193[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 32, 32, 128)  73856       ['activation_120[0][0]']
#
#  batch_normalization_194 (Batch  (None, 32, 32, 128)  512        ['conv2d_214[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_194[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 32, 32, 128)  8320        ['multiply_52[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 32, 32, 128)  147584      ['activation_121[0][0]']
#
#  batch_normalization_195 (Batch  (None, 32, 32, 128)  512        ['conv2d_216[0][0]']
#  Normalization)
#
#  add_63 (Add)                   (None, 32, 32, 128)  0           ['conv2d_215[0][0]',
#                                                                   'batch_normalization_195[0][0]']
#
#  global_average_pooling2d_38 (G  (None, 128)         0           ['add_63[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_38 (Reshape)           (None, 1, 1, 128)    0           ['global_average_pooling2d_38[0][
#                                                                  0]']
#
#  dense_76 (Dense)               (None, 1, 1, 16)     2048        ['reshape_38[0][0]']
#
#  dense_77 (Dense)               (None, 1, 1, 128)    2048        ['dense_76[0][0]']
#
#  multiply_53 (Multiply)         (None, 32, 32, 128)  0           ['add_63[0][0]',
#                                                                   'dense_77[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 32, 32, 256)  295168      ['multiply_53[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 32, 32, 256)  295168      ['multiply_53[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 32, 32, 256)  295168      ['multiply_53[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 32, 32, 256)  295168      ['multiply_53[0][0]']
#
#  batch_normalization_196 (Batch  (None, 32, 32, 256)  1024       ['conv2d_217[0][0]']
#  Normalization)
#
#  batch_normalization_197 (Batch  (None, 32, 32, 256)  1024       ['conv2d_218[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 32, 32, 256)  1024       ['conv2d_219[0][0]']
#  Normalization)
#
#  batch_normalization_199 (Batch  (None, 32, 32, 256)  1024       ['conv2d_220[0][0]']
#  Normalization)
#
#  add_64 (Add)                   (None, 32, 32, 256)  0           ['batch_normalization_196[0][0]',
#                                                                   'batch_normalization_197[0][0]',
#                                                                   'batch_normalization_198[0][0]',
#                                                                   'batch_normalization_199[0][0]']
#
#  batch_normalization_200 (Batch  (None, 64, 64, 64)  256         ['multiply_52[0][0]']
#  Normalization)
#
#  conv2d_221 (Conv2D)            (None, 32, 32, 256)  65792       ['add_64[0][0]']
#
#  activation_122 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 32, 32, 256)  1024       ['conv2d_221[0][0]']
#  Normalization)
#
#  conv2d_222 (Conv2D)            (None, 64, 64, 256)  147712      ['activation_122[0][0]']
#
#  activation_123 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_201[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 32, 32, 256)  0          ['conv2d_222[0][0]']
#  )
#
#  conv2d_223 (Conv2D)            (None, 32, 32, 256)  590080      ['activation_123[0][0]']
#
#  add_65 (Add)                   (None, 32, 32, 256)  0           ['max_pooling2d_15[0][0]',
#                                                                   'conv2d_223[0][0]']
#
#  batch_normalization_202 (Batch  (None, 32, 32, 256)  1024       ['add_65[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_202[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 32, 32, 256)  590080      ['activation_124[0][0]']
#
#  multiply_54 (Multiply)         (None, 32, 32, 256)  0           ['conv2d_224[0][0]',
#                                                                   'conv2d_221[0][0]']
#
#  up_sampling2d_15 (UpSampling2D  (None, 64, 64, 256)  0          ['multiply_54[0][0]']
#  )
#
#  concatenate_15 (Concatenate)   (None, 64, 64, 320)  0           ['up_sampling2d_15[0][0]',
#                                                                   'multiply_52[0][0]']
#
#  batch_normalization_203 (Batch  (None, 64, 64, 320)  1280       ['concatenate_15[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 64, 64, 320)  0           ['batch_normalization_203[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 64, 64, 128)  368768      ['activation_125[0][0]']
#
#  batch_normalization_204 (Batch  (None, 64, 64, 128)  512        ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_204[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 64, 64, 128)  41088       ['concatenate_15[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_126[0][0]']
#
#  batch_normalization_205 (Batch  (None, 64, 64, 128)  512        ['conv2d_227[0][0]']
#  Normalization)
#
#  add_66 (Add)                   (None, 64, 64, 128)  0           ['conv2d_226[0][0]',
#                                                                   'batch_normalization_205[0][0]']
#
#  global_average_pooling2d_39 (G  (None, 128)         0           ['add_66[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_39 (Reshape)           (None, 1, 1, 128)    0           ['global_average_pooling2d_39[0][
#                                                                  0]']
#
#  dense_78 (Dense)               (None, 1, 1, 16)     2048        ['reshape_39[0][0]']
#
#  dense_79 (Dense)               (None, 1, 1, 128)    2048        ['dense_78[0][0]']
#
#  batch_normalization_206 (Batch  (None, 128, 128, 32  128        ['multiply_51[0][0]']
#  Normalization)                 )
#
#  multiply_55 (Multiply)         (None, 64, 64, 128)  0           ['add_66[0][0]',
#                                                                   'dense_79[0][0]']
#
#  activation_127 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_206[0][0]']
#                                 )
#
#  batch_normalization_207 (Batch  (None, 64, 64, 128)  512        ['multiply_55[0][0]']
#  Normalization)
#
#  conv2d_228 (Conv2D)            (None, 128, 128, 12  36992       ['activation_127[0][0]']
#                                 8)
#
#  activation_128 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_207[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 64, 64, 128)  0          ['conv2d_228[0][0]']
#  )
#
#  conv2d_229 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_128[0][0]']
#
#  add_67 (Add)                   (None, 64, 64, 128)  0           ['max_pooling2d_16[0][0]',
#                                                                   'conv2d_229[0][0]']
#
#  batch_normalization_208 (Batch  (None, 64, 64, 128)  512        ['add_67[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_208[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_129[0][0]']
#
#  multiply_56 (Multiply)         (None, 64, 64, 128)  0           ['conv2d_230[0][0]',
#                                                                   'multiply_55[0][0]']
#
#  up_sampling2d_16 (UpSampling2D  (None, 128, 128, 12  0          ['multiply_56[0][0]']
#  )                              8)
#
#  concatenate_16 (Concatenate)   (None, 128, 128, 16  0           ['up_sampling2d_16[0][0]',
#                                 0)                                'multiply_51[0][0]']
#
#  batch_normalization_209 (Batch  (None, 128, 128, 16  640        ['concatenate_16[0][0]']
#  Normalization)                 0)
#
#  activation_130 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_209[0][0]']
#                                 0)
#
#  conv2d_231 (Conv2D)            (None, 128, 128, 64  92224       ['activation_130[0][0]']
#                                 )
#
#  batch_normalization_210 (Batch  (None, 128, 128, 64  256        ['conv2d_231[0][0]']
#  Normalization)                 )
#
#  activation_131 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_210[0][0]']
#                                 )
#
#  conv2d_233 (Conv2D)            (None, 128, 128, 64  10304       ['concatenate_16[0][0]']
#                                 )
#
#  conv2d_232 (Conv2D)            (None, 128, 128, 64  36928       ['activation_131[0][0]']
#                                 )
#
#  batch_normalization_211 (Batch  (None, 128, 128, 64  256        ['conv2d_233[0][0]']
#  Normalization)                 )
#
#  add_68 (Add)                   (None, 128, 128, 64  0           ['conv2d_232[0][0]',
#                                 )                                 'batch_normalization_211[0][0]']
#
#  global_average_pooling2d_40 (G  (None, 64)          0           ['add_68[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_40 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_40[0][
#                                                                  0]']
#
#  dense_80 (Dense)               (None, 1, 1, 8)      512         ['reshape_40[0][0]']
#
#  dense_81 (Dense)               (None, 1, 1, 64)     512         ['dense_80[0][0]']
#
#  batch_normalization_212 (Batch  (None, 256, 256, 16  64         ['multiply_50[0][0]']
#  Normalization)                 )
#
#  multiply_57 (Multiply)         (None, 128, 128, 64  0           ['add_68[0][0]',
#                                 )                                 'dense_81[0][0]']
#
#  activation_132 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_212[0][0]']
#                                 )
#
#  batch_normalization_213 (Batch  (None, 128, 128, 64  256        ['multiply_57[0][0]']
#  Normalization)                 )
#
#  conv2d_234 (Conv2D)            (None, 256, 256, 64  9280        ['activation_132[0][0]']
#                                 )
#
#  activation_133 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_213[0][0]']
#                                 )
#
#  max_pooling2d_17 (MaxPooling2D  (None, 128, 128, 64  0          ['conv2d_234[0][0]']
#  )                              )
#
#  conv2d_235 (Conv2D)            (None, 128, 128, 64  36928       ['activation_133[0][0]']
#                                 )
#
#  add_69 (Add)                   (None, 128, 128, 64  0           ['max_pooling2d_17[0][0]',
#                                 )                                 'conv2d_235[0][0]']
#
#  batch_normalization_214 (Batch  (None, 128, 128, 64  256        ['add_69[0][0]']
#  Normalization)                 )
#
#  activation_134 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_214[0][0]']
#                                 )
#
#  conv2d_236 (Conv2D)            (None, 128, 128, 64  36928       ['activation_134[0][0]']
#                                 )
#
#  multiply_58 (Multiply)         (None, 128, 128, 64  0           ['conv2d_236[0][0]',
#                                 )                                 'multiply_57[0][0]']
#
#  up_sampling2d_17 (UpSampling2D  (None, 256, 256, 64  0          ['multiply_58[0][0]']
#  )                              )
#
#  concatenate_17 (Concatenate)   (None, 256, 256, 80  0           ['up_sampling2d_17[0][0]',
#                                 )                                 'multiply_50[0][0]']
#
#  batch_normalization_215 (Batch  (None, 256, 256, 80  320        ['concatenate_17[0][0]']
#  Normalization)                 )
#
#  activation_135 (Activation)    (None, 256, 256, 80  0           ['batch_normalization_215[0][0]']
#                                 )
#
#  conv2d_237 (Conv2D)            (None, 256, 256, 32  23072       ['activation_135[0][0]']
#                                 )
#
#  batch_normalization_216 (Batch  (None, 256, 256, 32  128        ['conv2d_237[0][0]']
#  Normalization)                 )
#
#  activation_136 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_216[0][0]']
#                                 )
#
#  conv2d_239 (Conv2D)            (None, 256, 256, 32  2592        ['concatenate_17[0][0]']
#                                 )
#
#  conv2d_238 (Conv2D)            (None, 256, 256, 32  9248        ['activation_136[0][0]']
#                                 )
#
#  batch_normalization_217 (Batch  (None, 256, 256, 32  128        ['conv2d_239[0][0]']
#  Normalization)                 )
#
#  add_70 (Add)                   (None, 256, 256, 32  0           ['conv2d_238[0][0]',
#                                 )                                 'batch_normalization_217[0][0]']
#
#  global_average_pooling2d_41 (G  (None, 32)          0           ['add_70[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_41 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_41[0][
#                                                                  0]']
#
#  dense_82 (Dense)               (None, 1, 1, 4)      128         ['reshape_41[0][0]']
#
#  dense_83 (Dense)               (None, 1, 1, 32)     128         ['dense_82[0][0]']
#
#  multiply_59 (Multiply)         (None, 256, 256, 32  0           ['add_70[0][0]',
#                                 )                                 'dense_83[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 256, 256, 16  4624        ['multiply_59[0][0]']
#                                 )
#
#  conv2d_241 (Conv2D)            (None, 256, 256, 16  4624        ['multiply_59[0][0]']
#                                 )
#
#  conv2d_242 (Conv2D)            (None, 256, 256, 16  4624        ['multiply_59[0][0]']
#                                 )
#
#  conv2d_243 (Conv2D)            (None, 256, 256, 16  4624        ['multiply_59[0][0]']
#                                 )
#
#  batch_normalization_218 (Batch  (None, 256, 256, 16  64         ['conv2d_240[0][0]']
#  Normalization)                 )
#
#  batch_normalization_219 (Batch  (None, 256, 256, 16  64         ['conv2d_241[0][0]']
#  Normalization)                 )
#
#  batch_normalization_220 (Batch  (None, 256, 256, 16  64         ['conv2d_242[0][0]']
#  Normalization)                 )
#
#  batch_normalization_221 (Batch  (None, 256, 256, 16  64         ['conv2d_243[0][0]']
#  Normalization)                 )
#
#  add_71 (Add)                   (None, 256, 256, 16  0           ['batch_normalization_218[0][0]',
#                                 )                                 'batch_normalization_219[0][0]',
#                                                                   'batch_normalization_220[0][0]',
#                                                                   'batch_normalization_221[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 256, 256, 16  272         ['add_71[0][0]']
#                                 )
#
#  conv2d_245 (Conv2D)            (None, 256, 256, 1)  17          ['conv2d_244[0][0]']
#
#  activation_137 (Activation)    (None, 256, 256, 1)  0           ['conv2d_245[0][0]']
#
# ==================================================================================================
# Total params: 4,070,385
# Trainable params: 4,062,993
# Non-trainable params: 7,392
# __________________________________________________________________________________________________
